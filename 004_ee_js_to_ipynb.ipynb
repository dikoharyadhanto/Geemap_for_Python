# %% [markdown]
# <a href="https://colab.research.google.com/github/dikoharyadhanto/Geemap_for_Python/blob/main/008_ee_js_to_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/08_ee_js_to_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geemap
#   Downloading geemap-0.20.4-py2.py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: earthengine-api>=0.1.304 in /usr/local/lib/python3.9/dist-packages (from geemap) (0.1.346)
# Collecting ipyfilechooser>=0.6.0
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting geojson
#   Downloading geojson-3.0.1-py3-none-any.whl (15 kB)
# Collecting ipyevents
#   Downloading ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 KB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from geemap) (8.4.0)
# Requirement already satisfied: folium>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from geemap) (0.14.0)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/dist-packages (from geemap) (4.6.6)
# Collecting bqplot
#   Downloading bqplot-0.12.37-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.0 MB/s eta 0:00:00
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 KB 5.2 MB/s eta 0:00:00
# Collecting whiteboxgui>=0.6.0
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 KB 5.2 MB/s eta 0:00:00
# Collecting ipyleaflet>=0.17.0
#   Downloading ipyleaflet-0.17.2-py3-none-any.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 53.8 MB/s eta 0:00:00
# Collecting scooby
#   Downloading scooby-0.7.1-py3-none-any.whl (16 kB)
# Collecting sankee>=0.1.0
#   Downloading sankee-0.2.3.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipywidgets<8.0.0 in /usr/local/lib/python3.9/dist-packages (from geemap) (7.7.1)
# Collecting ee-extra>=0.0.10
#   Downloading ee_extra-0.0.15.tar.gz (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 KB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycrs
#   Downloading PyCRS-1.0.2.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyshp>=2.1.3
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 KB 3.0 MB/s eta 0:00:00
# Collecting xyzservices
#   Downloading xyzservices-2023.2.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 KB 1.7 MB/s eta 0:00:00
# Collecting ipytree
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from geemap) (3.7.1)
# Collecting geeadd>=0.5.1
#   Downloading geeadd-0.5.6-py3-none-any.whl (30 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from geemap) (1.4.4)
# Collecting python-box
#   Downloading python_box-7.0.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 24.3 MB/s eta 0:00:00
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting eerepr>=0.0.4
#   Downloading eerepr-0.0.4-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from geemap) (1.22.4)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.9/dist-packages (from earthengine-api>=0.1.304->geemap) (2.70.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from earthengine-api>=0.1.304->geemap) (2.27.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from earthengine-api>=0.1.304->geemap) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from earthengine-api>=0.1.304->geemap) (0.21.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.9/dist-packages (from earthengine-api>=0.1.304->geemap) (2.7.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from earthengine-api>=0.1.304->geemap) (2.16.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from folium>=0.11.0->geemap) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.9/dist-packages (from folium>=0.11.0->geemap) (3.1.2)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /usr/local/lib/python3.9/dist-packages (from geeadd>=0.5.1->geemap) (4.11.2)
# Collecting logzero>=1.5.0
#   Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Collecting traittypes<3,>=0.2.1
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets<8.0.0->geemap) (5.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets<8.0.0->geemap) (3.0.6)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets<8.0.0->geemap) (3.6.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets<8.0.0->geemap) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets<8.0.0->geemap) (7.34.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets<8.0.0->geemap) (5.5.6)
# Requirement already satisfied: plotly>=5.2.2 in /usr/local/lib/python3.9/dist-packages (from sankee>=0.1.0->geemap) (5.13.1)
# Collecting whitebox
#   Downloading whitebox-2.3.1-py2.py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 KB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->geemap) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from ffmpeg-python->geemap) (0.18.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown->geemap) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown->geemap) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown->geemap) (3.10.7)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from geocoder->geemap) (8.1.3)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->geemap) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->geemap) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->geemap) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->geemap) (4.39.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (2.11.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.9)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->geemap) (3.15.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->geemap) (6.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (67.6.1)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 38.6 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (2.14.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0->geemap) (3.0.38)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.2.2->sankee>=0.1.0->geemap) (8.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->earthengine-api>=0.1.304->geemap) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->earthengine-api>=0.1.304->geemap) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->earthengine-api>=0.1.304->geemap) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->earthengine-api>=0.1.304->geemap) (3.4)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (6.3.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests->earthengine-api>=0.1.304->geemap) (1.7.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (3.19.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.304->geemap) (1.59.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.9/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.8.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (23.2.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (5.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.17.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (5.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (21.3.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0->geemap) (0.2.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.4.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (3.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (21.2.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.7.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (4.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (6.0.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (22.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0->geemap) (2.21)
# Building wheels for collected packages: ee-extra, sankee, pycrs, pyperclip
#   Building wheel for ee-extra (setup.py) ... done
#   Created wheel for ee-extra: filename=ee_extra-0.0.15-py3-none-any.whl size=236771 sha256=ebd854a1e4a30f86468766e05f3c9835b7af7b7e81eff9eec1ae7b321daa41f6
#   Stored in directory: /root/.cache/pip/wheels/66/66/06/98d6dee3f612d84d2b487fc73ca2c2479279dc2714faddcc10
#   Building wheel for sankee (setup.py) ... done
#   Created wheel for sankee: filename=sankee-0.2.3-py3-none-any.whl size=30511 sha256=18ec0f5adfa2cd28599874d7702c828aad94b3b94620c270a0209fd62f253f67
#   Stored in directory: /root/.cache/pip/wheels/a0/77/76/04746a9b2af1cfe05fbfb90463ee0a1e5a632e162d85e7cf33
#   Building wheel for pycrs (setup.py) ... done
#   Created wheel for pycrs: filename=PyCRS-1.0.2-py3-none-any.whl size=32702 sha256=4ec6f44bc9fa81a9c688d844021780cf93d532be16731c099e27fef157f51180
#   Stored in directory: /root/.cache/pip/wheels/94/01/24/bc7bff66667ef317615144a15e04593a08d9bb322f2c427d6c
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11135 sha256=08b825f27dee1970adcf785e69d8e34cdde0a50e6a1726cae3244c5b107f98d7
#   Stored in directory: /root/.cache/pip/wheels/0c/09/9e/49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
# Successfully built ee-extra sankee pycrs pyperclip
# Installing collected packages: pyperclip, pycrs, logzero, colour, xyzservices, whitebox, traittypes, scooby, ratelim, python-box, pyshp, jedi, geojson, ffmpeg-python, geocoder, geeadd, eerepr, ee-extra, sankee, ipytree, ipyleaflet, ipyfilechooser, ipyevents, bqplot, whiteboxgui, geemap
# Successfully installed bqplot-0.12.37 colour-0.1.5 ee-extra-0.0.15 eerepr-0.0.4 ffmpeg-python-0.2.0 geeadd-0.5.6 geemap-0.20.4 geocoder-1.38.1 geojson-3.0.1 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipyleaflet-0.17.2 ipytree-0.2.2 jedi-0.18.2 logzero-1.7.0 pycrs-1.0.2 pyperclip-1.8.2 pyshp-2.3.1 python-box-7.0.1 ratelim-0.1.6 sankee-0.2.3 scooby-0.7.1 traittypes-0.2.1 whitebox-2.3.1 whiteboxgui-2.3.0 xyzservices-2023.2.0

# %% [markdown]
# ## Automatic conversion from Earth Engine JavaScripts to Python scripts
#
# ### Install Earth Engine API and geemap
# Install the [Earth Engine Python API](https://developers.google.com/earth-engine/python_install) and [geemap](https://github.com/giswqs/geemap). The **geemap** Python package is built upon the [ipyleaflet](https://github.com/jupyter-widgets/ipyleaflet) and [folium](https://github.com/python-visualization/folium) packages and implements several methods for interacting with Earth Engine data layers, such as `Map.addLayer()`, `Map.setCenter()`, and `Map.centerObject()`.
# The following script checks if the geemap package has been installed. If not, it will install geemap, which automatically installs its [dependencies](https://github.com/giswqs/geemap#dependencies), including earthengine-api, folium, and ipyleaflet.
#
# **Important note**: A key difference between folium and ipyleaflet is that ipyleaflet is built upon ipywidgets and allows bidirectional communication between the front-end and the backend enabling the use of the map to capture user input, while folium is meant for displaying static data only ([source](https://blog.jupyter.org/interactive-gis-in-jupyter-with-ipyleaflet-52f9657fa7a)). Note that [Google Colab](https://colab.research.google.com/) currently does not support ipyleaflet ([source](https://github.com/googlecolab/colabtools/issues/60#issuecomment-596225619)). Therefore, if you are using geemap with Google Colab, you should use [`import geemap.foliumap`](https://github.com/giswqs/geemap/blob/master/geemap/foliumap.py). If you are using geemap with [binder](https://mybinder.org/) or a local Jupyter notebook server, you can use [`import geemap`](https://github.com/giswqs/geemap/blob/master/geemap/geemap.py), which provides more functionalities for capturing user input (e.g., mouse-clicking and moving).

# %%
import geemap
import os

# %% [markdown]
# ### Directory setting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/earth-engine API")

# %% [markdown]
# ### Convert Earth Engine JavaScripts to Python scripts

# %%
from geemap.conversion import *

# Get Earth Engine JavaScript examples. There are five examples in the geemap package folder.
# Change js_dir to your own folder containing your Earth Engine JavaScripts,
# such as js_dir = '/path/to/your/js/folder'
js_dir = '/content/drive/MyDrive/earth-engine API/javascript'
py_dir = '/content/drive/MyDrive/earth-engine API/Python'

# Convert all Earth Engine JavaScripts in a folder recursively to Python scripts.
js_to_python_dir(in_dir=js_dir, out_dir=py_dir, use_qgis=True)
print("Python scripts saved at: {}".format(py_dir))
# Out:
# Converting Earth Engine JavaScripts to Python scripts...
#
# Processing 1/79: /content/drive/MyDrive/earth-engine API/javascript/Primitive/DictionaryGet.js
# Processing 2/79: /content/drive/MyDrive/earth-engine API/javascript/Demos/Sentinel1Composite.js
# Processing 3/79: /content/drive/MyDrive/earth-engine API/javascript/Demos/EgyptClassification.js
# Processing 4/79: /content/drive/MyDrive/earth-engine API/javascript/Demos/TerrainVisualization.js
# Processing 5/79: /content/drive/MyDrive/earth-engine API/javascript/Demos/MODISHarmonicModeling.js
# Processing 6/79: /content/drive/MyDrive/earth-engine API/javascript/Demos/Landsat8HarmonicModeling.js
# Processing 7/79: /content/drive/MyDrive/earth-engine API/javascript/Demos/Classification.js
# Processing 8/79: /content/drive/MyDrive/earth-engine API/javascript/Demos/NASANEXClimateModeling.js
# Processing 9/79: /content/drive/MyDrive/earth-engine API/javascript/CloudMasking/Landsat8SurfaceReflectance.js
# Processing 10/79: /content/drive/MyDrive/earth-engine API/javascript/CloudMasking/MODISSurfaceReflectanceQABand.js
# Processing 11/79: /content/drive/MyDrive/earth-engine API/javascript/CloudMasking/Landsat457SurfaceReflectance.js
# Processing 12/79: /content/drive/MyDrive/earth-engine API/javascript/CloudMasking/Landsat8TOAReflectanceQABand.js
# Processing 13/79: /content/drive/MyDrive/earth-engine API/javascript/CloudMasking/Sentinel2CloudAndShadow.js
# Processing 14/79: /content/drive/MyDrive/earth-engine API/javascript/CloudMasking/Sentinel2.js
# Processing 15/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/ImageSpectra.js
# Processing 16/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/ElevationAndTemperature.js
# Processing 17/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/ElevationProfile.js
# Processing 18/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/ImageTimeSeries.js
# Processing 19/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/TemperatureDisparity.js
# Processing 20/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/DoySeries.js
# Processing 21/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/ImageTimeSeriesByRegion.js
# Processing 22/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/ColumnHistogram.js
# Processing 23/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/SeasonalTemperatures.js
# Processing 24/79: /content/drive/MyDrive/earth-engine API/javascript/Charts/ElevationHistogram.js
# Processing 25/79: /content/drive/MyDrive/earth-engine API/javascript/CodeEditor/MapStyle.js
# Processing 26/79: /content/drive/MyDrive/earth-engine API/javascript/CodeEditor/MapCenterObject.js
# Processing 27/79: /content/drive/MyDrive/earth-engine API/javascript/FeatureCollection/Buffer.js
# Processing 28/79: /content/drive/MyDrive/earth-engine API/javascript/FeatureCollection/Distance.js
# Processing 29/79: /content/drive/MyDrive/earth-engine API/javascript/FeatureCollection/ComputedAreaFilter.js
# Processing 30/79: /content/drive/MyDrive/earth-engine API/javascript/FeatureCollection/FromEarthEngineAsset.js
# Processing 31/79: /content/drive/MyDrive/earth-engine API/javascript/FeatureCollection/FromPolygons.js
# Processing 32/79: /content/drive/MyDrive/earth-engine API/javascript/FeatureCollection/ReduceToImage.js
# Processing 33/79: /content/drive/MyDrive/earth-engine API/javascript/FeatureCollection/Join.js
# Processing 34/79: /content/drive/MyDrive/earth-engine API/javascript/tutorials/jrc_gsw/tutorial_global_surface_water_03.js
# Processing 35/79: /content/drive/MyDrive/earth-engine API/javascript/tutorials/jrc_gsw/tutorial_global_surface_water_04.js
# Processing 36/79: /content/drive/MyDrive/earth-engine API/javascript/tutorials/jrc_gsw/tutorial_global_surface_water_02.js
# Processing 37/79: /content/drive/MyDrive/earth-engine API/javascript/Image/LandcoverCleanup.js
# Processing 38/79: /content/drive/MyDrive/earth-engine API/javascript/Image/ModisQaBands.js
# Processing 39/79: /content/drive/MyDrive/earth-engine API/javascript/Image/ReduceRegion.js
# Processing 40/79: /content/drive/MyDrive/earth-engine API/javascript/Image/CannyEdgeDetector.js
# Processing 41/79: /content/drive/MyDrive/earth-engine API/javascript/Image/Expression.js
# Processing 42/79: /content/drive/MyDrive/earth-engine API/javascript/Image/HoughTransform.js
# Processing 43/79: /content/drive/MyDrive/earth-engine API/javascript/Image/FromName.js
# Processing 44/79: /content/drive/MyDrive/earth-engine API/javascript/Image/PixelArea.js
# Processing 45/79: /content/drive/MyDrive/earth-engine API/javascript/Image/ConnectedPixelCount.js
# Processing 46/79: /content/drive/MyDrive/earth-engine API/javascript/Image/Polynomial.js
# Processing 47/79: /content/drive/MyDrive/earth-engine API/javascript/Image/HSVPanSharpening.js
# Processing 48/79: /content/drive/MyDrive/earth-engine API/javascript/Image/CenterPivotIrrigationDetector.js
# Processing 49/79: /content/drive/MyDrive/earth-engine API/javascript/Image/Clamp.js
# Processing 50/79: /content/drive/MyDrive/earth-engine API/javascript/Image/PixelLonLat.js
# Processing 51/79: /content/drive/MyDrive/earth-engine API/javascript/Image/NormalizedDifference.js
# Processing 52/79: /content/drive/MyDrive/earth-engine API/javascript/Image/Hillshade.js
# Processing 53/79: /content/drive/MyDrive/earth-engine API/javascript/Image/ZeroCrossing.js
# Processing 54/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/MosaicEditor.js
# Processing 55/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/TwoChartInspector.js
# Processing 56/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/OceanTimeseriesInvestigator.js
# Processing 57/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/CollectionSlider.js
# Processing 58/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/ManualLegend.js
# Processing 59/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/MobileFriendlyUI.js
# Processing 60/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/ForestChange.js
# Processing 61/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/SplitPanel.js
# Processing 62/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/PopulationExplorer.js
# Processing 63/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/ZoomBox.js
# Processing 64/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/LinkedMaps.js
# Processing 65/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/AsyncInspector.js
# Processing 66/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/LandsatExplorer.js
# Processing 67/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/LayerFilters.js
# Processing 68/79: /content/drive/MyDrive/earth-engine API/javascript/UserInterface/AirstripThumbnails.js
# Processing 69/79: /content/drive/MyDrive/earth-engine API/javascript/ImageCollection/FilteredComposite.js
# Processing 70/79: /content/drive/MyDrive/earth-engine API/javascript/ImageCollection/SimpleCloudScore.js
# Processing 71/79: /content/drive/MyDrive/earth-engine API/javascript/ImageCollection/AnimatedThumbnail.js
# Processing 72/79: /content/drive/MyDrive/earth-engine API/javascript/ImageCollection/LinearFit.js
# Processing 73/79: /content/drive/MyDrive/earth-engine API/javascript/ImageCollection/ClippedComposite.js
# Processing 74/79: /content/drive/MyDrive/earth-engine API/javascript/ImageCollection/ExpressionMap.js
# Processing 75/79: /content/drive/MyDrive/earth-engine API/javascript/ImageCollection/LandsatSimpleComposite.js
# An error occurred when processing /content/drive/MyDrive/earth-engine API/javascript/ImageCollection/LandsatSimpleComposite.js. The closing curly bracket could not be found in Line 24: function TOAComposite(collection,
# . Please reformat the function definition and make sure that both the opening and closing curly brackets apprear on the same line as the function keyword.
# Processing 76/79: /content/drive/MyDrive/earth-engine API/javascript/Arrays/DecorrelationStretch.js
# Processing 77/79: /content/drive/MyDrive/earth-engine API/javascript/Arrays/QualityMosaic.js
# Processing 78/79: /content/drive/MyDrive/earth-engine API/javascript/Arrays/LinearRegression.js
# Processing 79/79: /content/drive/MyDrive/earth-engine API/javascript/Arrays/SpectralUnmixing.js
# Python scripts saved at: /content/drive/MyDrive/earth-engine API/Python

# %% [markdown]
# ### Convert Earth Engine Python scripts to Jupyter Notebooks

# %%
# Convert all Earth Engine Python scripts in a folder recursively to Jupyter notebooks.
nb_template = get_nb_template()  # Get the notebook template from the package folder.
py_to_ipynb_dir(py_dir, nb_template)

# Execute all Jupyter notebooks in a folder recursively and save the output cells.
execute_notebook_dir(in_dir=py_dir)
# Out:
# Converting Earth Engine Python scripts to Jupyter notebooks ...
#
# Processing 1/78: /content/drive/MyDrive/earth-engine API/Python/Primitive/DictionaryGet_geemap.py
#
# Processing 2/78: /content/drive/MyDrive/earth-engine API/Python/Demos/Sentinel1Composite_geemap.py
#
# Processing 3/78: /content/drive/MyDrive/earth-engine API/Python/Demos/EgyptClassification_geemap.py
#
# Processing 4/78: /content/drive/MyDrive/earth-engine API/Python/Demos/TerrainVisualization_geemap.py
#
# Processing 5/78: /content/drive/MyDrive/earth-engine API/Python/Demos/MODISHarmonicModeling_geemap.py
#
# Processing 6/78: /content/drive/MyDrive/earth-engine API/Python/Demos/Landsat8HarmonicModeling_geemap.py
#
# Processing 7/78: /content/drive/MyDrive/earth-engine API/Python/Demos/Classification_geemap.py
#
# Processing 8/78: /content/drive/MyDrive/earth-engine API/Python/Demos/NASANEXClimateModeling_geemap.py
#
# Processing 9/78: /content/drive/MyDrive/earth-engine API/Python/CloudMasking/Landsat8SurfaceReflectance_geemap.py
#
# Processing 10/78: /content/drive/MyDrive/earth-engine API/Python/CloudMasking/MODISSurfaceReflectanceQABand_geemap.py
#
# Processing 11/78: /content/drive/MyDrive/earth-engine API/Python/CloudMasking/Landsat457SurfaceReflectance_geemap.py
#
# Processing 12/78: /content/drive/MyDrive/earth-engine API/Python/CloudMasking/Landsat8TOAReflectanceQABand_geemap.py
#
# Processing 13/78: /content/drive/MyDrive/earth-engine API/Python/CloudMasking/Sentinel2CloudAndShadow_geemap.py
#
# Processing 14/78: /content/drive/MyDrive/earth-engine API/Python/CloudMasking/Sentinel2_geemap.py
#
# Processing 15/78: /content/drive/MyDrive/earth-engine API/Python/Charts/ImageSpectra_geemap.py
#
# Processing 16/78: /content/drive/MyDrive/earth-engine API/Python/Charts/ElevationAndTemperature_geemap.py
#
# Processing 17/78: /content/drive/MyDrive/earth-engine API/Python/Charts/ElevationProfile_geemap.py
#
# Processing 18/78: /content/drive/MyDrive/earth-engine API/Python/Charts/ImageTimeSeries_geemap.py
#
# Processing 19/78: /content/drive/MyDrive/earth-engine API/Python/Charts/TemperatureDisparity_geemap.py
#
# Processing 20/78: /content/drive/MyDrive/earth-engine API/Python/Charts/DoySeries_geemap.py
#
# Processing 21/78: /content/drive/MyDrive/earth-engine API/Python/Charts/ImageTimeSeriesByRegion_geemap.py
#
# Processing 22/78: /content/drive/MyDrive/earth-engine API/Python/Charts/ColumnHistogram_geemap.py
#
# Processing 23/78: /content/drive/MyDrive/earth-engine API/Python/Charts/SeasonalTemperatures_geemap.py
#
# Processing 24/78: /content/drive/MyDrive/earth-engine API/Python/Charts/ElevationHistogram_geemap.py
#
# Processing 25/78: /content/drive/MyDrive/earth-engine API/Python/CodeEditor/MapStyle_geemap.py
#
# Processing 26/78: /content/drive/MyDrive/earth-engine API/Python/CodeEditor/MapCenterObject_geemap.py
#
# Processing 27/78: /content/drive/MyDrive/earth-engine API/Python/FeatureCollection/Buffer_geemap.py
#
# Processing 28/78: /content/drive/MyDrive/earth-engine API/Python/FeatureCollection/Distance_geemap.py
#
# Processing 29/78: /content/drive/MyDrive/earth-engine API/Python/FeatureCollection/ComputedAreaFilter_geemap.py
#
# Processing 30/78: /content/drive/MyDrive/earth-engine API/Python/FeatureCollection/FromEarthEngineAsset_geemap.py
#
# Processing 31/78: /content/drive/MyDrive/earth-engine API/Python/FeatureCollection/FromPolygons_geemap.py
#
# Processing 32/78: /content/drive/MyDrive/earth-engine API/Python/FeatureCollection/ReduceToImage_geemap.py
#
# Processing 33/78: /content/drive/MyDrive/earth-engine API/Python/FeatureCollection/Join_geemap.py
#
# Processing 34/78: /content/drive/MyDrive/earth-engine API/Python/tutorials/jrc_gsw/tutorial_global_surface_water_03_geemap.py
#
# Processing 35/78: /content/drive/MyDrive/earth-engine API/Python/tutorials/jrc_gsw/tutorial_global_surface_water_04_geemap.py
#
# Processing 36/78: /content/drive/MyDrive/earth-engine API/Python/tutorials/jrc_gsw/tutorial_global_surface_water_02_geemap.py
#
# Processing 37/78: /content/drive/MyDrive/earth-engine API/Python/Image/LandcoverCleanup_geemap.py
#
# Processing 38/78: /content/drive/MyDrive/earth-engine API/Python/Image/ModisQaBands_geemap.py
#
# Processing 39/78: /content/drive/MyDrive/earth-engine API/Python/Image/ReduceRegion_geemap.py
#
# Processing 40/78: /content/drive/MyDrive/earth-engine API/Python/Image/CannyEdgeDetector_geemap.py
#
# Processing 41/78: /content/drive/MyDrive/earth-engine API/Python/Image/Expression_geemap.py
#
# Processing 42/78: /content/drive/MyDrive/earth-engine API/Python/Image/HoughTransform_geemap.py
#
# Processing 43/78: /content/drive/MyDrive/earth-engine API/Python/Image/FromName_geemap.py
#
# Processing 44/78: /content/drive/MyDrive/earth-engine API/Python/Image/PixelArea_geemap.py
#
# Processing 45/78: /content/drive/MyDrive/earth-engine API/Python/Image/ConnectedPixelCount_geemap.py
#
# Processing 46/78: /content/drive/MyDrive/earth-engine API/Python/Image/Polynomial_geemap.py
#
# Processing 47/78: /content/drive/MyDrive/earth-engine API/Python/Image/HSVPanSharpening_geemap.py
#
# Processing 48/78: /content/drive/MyDrive/earth-engine API/Python/Image/CenterPivotIrrigationDetector_geemap.py
#
# Processing 49/78: /content/drive/MyDrive/earth-engine API/Python/Image/Clamp_geemap.py
#
# Processing 50/78: /content/drive/MyDrive/earth-engine API/Python/Image/PixelLonLat_geemap.py
#
# Processing 51/78: /content/drive/MyDrive/earth-engine API/Python/Image/NormalizedDifference_geemap.py
#
# Processing 52/78: /content/drive/MyDrive/earth-engine API/Python/Image/Hillshade_geemap.py
#
# Processing 53/78: /content/drive/MyDrive/earth-engine API/Python/Image/ZeroCrossing_geemap.py
#
# Processing 54/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/MosaicEditor_geemap.py
#
# Processing 55/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/TwoChartInspector_geemap.py
#
# Processing 56/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/OceanTimeseriesInvestigator_geemap.py
#
# Processing 57/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/CollectionSlider_geemap.py
#
# Processing 58/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/ManualLegend_geemap.py
#
# Processing 59/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/MobileFriendlyUI_geemap.py
#
# Processing 60/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/ForestChange_geemap.py
#
# Processing 61/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/SplitPanel_geemap.py
#
# Processing 62/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/PopulationExplorer_geemap.py
#
# Processing 63/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/ZoomBox_geemap.py
#
# Processing 64/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/LinkedMaps_geemap.py
#
# Processing 65/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/AsyncInspector_geemap.py
#
# Processing 66/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/LandsatExplorer_geemap.py
#
# Processing 67/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/LayerFilters_geemap.py
#
# Processing 68/78: /content/drive/MyDrive/earth-engine API/Python/UserInterface/AirstripThumbnails_geemap.py
#
# Processing 69/78: /content/drive/MyDrive/earth-engine API/Python/ImageCollection/FilteredComposite_geemap.py
#
# Processing 70/78: /content/drive/MyDrive/earth-engine API/Python/ImageCollection/SimpleCloudScore_geemap.py
#
# Processing 71/78: /content/drive/MyDrive/earth-engine API/Python/ImageCollection/AnimatedThumbnail_geemap.py
#
# Processing 72/78: /content/drive/MyDrive/earth-engine API/Python/ImageCollection/LinearFit_geemap.py
#
# Processing 73/78: /content/drive/MyDrive/earth-engine API/Python/ImageCollection/ClippedComposite_geemap.py
#
# Processing 74/78: /content/drive/MyDrive/earth-engine API/Python/ImageCollection/ExpressionMap_geemap.py
#
# Processing 75/78: /content/drive/MyDrive/earth-engine API/Python/Arrays/DecorrelationStretch_geemap.py
#
# Processing 76/78: /content/drive/MyDrive/earth-engine API/Python/Arrays/QualityMosaic_geemap.py
#
# Processing 77/78: /content/drive/MyDrive/earth-engine API/Python/Arrays/LinearRegression_geemap.py
#
# Processing 78/78: /content/drive/MyDrive/earth-engine API/Python/Arrays/SpectralUnmixing_geemap.py
#
# Executing Earth Engine Jupyter notebooks ...
