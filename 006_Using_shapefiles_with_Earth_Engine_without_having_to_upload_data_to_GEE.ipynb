# %% [markdown]
# <a href="https://colab.research.google.com/github/dikoharyadhanto/Geemap_for_Python/blob/main/006_Using_shapefiles_with_Earth_Engine_without_having_to_upload_data_to_GEE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/dikoharyadhanto/Geemap_for_Python/
# Out:
# Cloning into 'Geemap_for_Python'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 77 (delta 39), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (77/77), 2.12 MiB | 1.78 MiB/s, done.

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 86.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 95.8 MB/s eta 0:00:00
# ...

# %%
# !pip install geemap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 37.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 92.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 86.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.4 MB/s eta 0:00:00
# ...

# %%
# !pip install pyshp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# !pip install pycrs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycrs: filename=PyCRS-1.0.2-py3-none-any.whl size=32686 sha256=2427e054a57e5bb2e376eccdbca4a942b3c29ef9b4a8469766f72d9a85a43d1e
#   Stored in directory: /root/.cache/pip/wheels/47/1d/70/7a5bdf33347e7c75e95b06b1fa38f076a59a9506653cc24aff
# Successfully built pycrs
# ...

# %%
import geemap
import geopandas as gpd
import zipfile

# %%
Map = geemap.Map()
Map
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=x6TmWYr0WSAGkdI0oERK4-BaNClX3jRQWUE7HSF_7Q4&tc=kBPx95aWXqDnJoeg8zOieoCUKhDbZTiThqhMtwN8ELY&cc=KvkePFwdLJ3a9AfqZzP2Zn0yK3a8Re30rmJzrEbWCNI
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AbUR2VODX013hspjxZYMcAOuNmekqcfbyRsGAPOMMoDIGLY3aS5HQrkaNrA
#
# Successfully saved authorization token.
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
#Extract Dataset ZIP
zip_ref = zipfile.ZipFile("/content/Geemap_for_Python/data/Jakarta_Kota.zip", 'r')
zip_ref.extractall("/content/Geemap_for_Python/data/DKI_Jakarta_Kec")
zip_ref.close()

# %%
jakarta_shp = '/content/Geemap_for_Python/data/DKI_Jakarta_Kec/Jakarta_Kota/Jakarta_Kota.shp'

jakarta_gdf = gpd.read_file(path)
jakarta_gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Convert SHP to EE Data

# %%
jakarta = geemap.shp_to_ee(jakarta_shp)
Map.addLayer(jakarta, {}, 'Jakarta')
# Out:
# WARNING:googleapiclient.http:Sleeping 0.44 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps?fields=name&alt=json, after EOF occurred in violation of protocol (_ssl.c:2426)

# %% [markdown]
# # Convert EE Data to SHP

# %%
geemap.ee_to_shp(jakarta, filename='/content/Geemap_for_Python/data/Jakarta_new/Jakarta_new.shp')
# Out:
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to /content/Geemap_for_Python/data/Jakarta_new/Jakarta_new.shp

# %% [markdown]
# # Convert EE Data to Other Data

# %%
#geemap.ee_export_vector(states, filename='../data/states.csv')

# %%
#geemap.ee_export_vector(states, filename='../data/states.kml')

# %%
#geemap.ee_export_vector(states, filename='../data/states.kmz')
